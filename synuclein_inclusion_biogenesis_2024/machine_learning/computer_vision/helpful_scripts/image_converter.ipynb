# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.filters import gaussian, threshold_otsu, threshold_multiotsu, sobel, threshold_sauvola
from skimage.morphology import remove_small_objects, disk, binary_closing
from scipy.ndimage import zoom, binary_dilation, binary_erosion, distance_transform_edt
from skimage.measure import label, regionprops
from skimage import io, exposure, color
from skimage import measure, morphology
from skimage import exposure
from czifile import imread
import cv2
import re
from matplotlib.ticker import MaxNLocator
import imageio.v2 as imageio  # or use `from imageio import imwrite` if you prefer

# %%
def display_image(image, path, type):
    """Display the image."""
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"{path} {type}")
    plt.show()

def extract_image_paths(folder):
    """Extract all image file paths from the specified folder."""
    return [os.path.join(folder, f) for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

def read_image(image_path):
    """Read the LSM image from the specified path."""
    return imread(image_path)

def extract_channels(image: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    """Extract green and red channels from the squeezed image (shape: [Z, C, H, W]).""" 
    return image[0], image[1], image[2]

def normalize_to_uint8(image):
    """Normalize a uint16 image to uint8 [0, 255] scale."""
    image = image.astype(np.float32)
    min_val = image.min()
    max_val = image.max()
    if max_val == min_val:
        return np.zeros_like(image, dtype=np.uint8)  # Avoid division by zero
    norm = (image - min_val) / (max_val - min_val)
    return (norm * 255).astype(np.uint8)
def extract_image_paths(folder):
    image_paths = []
    for root, _, files in os.walk(folder):
        for file in files:
            if file.lower().endswith(".czi"):
                image_paths.append(os.path.join(root, file))
    return image_paths

# %%
def main(image_folder):
    output_dir = "../images/converted"
    os.makedirs(output_dir, exist_ok=True)

    images_to_analyze = extract_image_paths(image_folder)

    for path in images_to_analyze:
        image = read_image(path)
        image_squeezed = np.squeeze(image)
        red, green, _ = extract_channels(image_squeezed)

        # derive subfolder name and base filename
        subfolder = os.path.basename(os.path.dirname(path))
        filename = os.path.splitext(os.path.basename(path))[0]

        save_path = os.path.join(output_dir, f"{subfolder}_{filename}.png")
        imageio.imwrite(save_path, green)
        print(f"Saved: {save_path}")


if __name__ == "__main__":
    image_folder = '../images/mitophagy_3K_inclusions'
    main(image_folder)
# Out:
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_01.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_010.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_011.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_012.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_013.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_014.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_015.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_016.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_017.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_018.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_019.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_02.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_020.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_021.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_022.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_023.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_024.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_025.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_03.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_04.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_05.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_06.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_07.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_08.png
# Saved: ../images/converted\080625_3K_dox_LAMP1RFP_mitoBFP_09.png
# Saved: ../images/converted\080625_3K_dox_only_01.png
# Saved: ../images/converted\080625_3K_dox_only_02.png
# Saved: ../images/converted\080625_3K_dox_only_03.png
# Saved: ../images/converted\080625_3K_dox_only_04.png
# Saved: ../images/converted\080625_3K_dox_only_05.png
# Saved: ../images/converted\080625_3K_dox_only_06.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_01.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_02.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_03.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_04.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_05.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_06.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_07.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_08.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_09.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_10.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_11.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_12.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_13.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_14.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_15.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_16.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_17.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_18.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_19.png
# Saved: ../images/converted\081125_3K_dox_LAMP1RFP_mitoBFP_20.png
# Saved: ../images/converted\081125_3K_dox_only_1.png
# Saved: ../images/converted\081125_3K_dox_only_2.png
# Saved: ../images/converted\081125_3K_dox_only_3.png
# Saved: ../images/converted\081125_3K_dox_only_4.png
# Saved: ../images/converted\081125_3K_dox_only_5.png
# Saved: ../images/converted\081125_3K_dox_only_6.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_01.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_02.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_03.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_04.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_05.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_06.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_07.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_08.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_09.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_10.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_11.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_12.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_13.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_14.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_15.png
# Saved: ../images/converted\081325_3K_dox_LAMP1RFP_mitoBFP_16.png
# Saved: ../images/converted\081325_3K_dox_LampRFP_only_1.png
# Saved: ../images/converted\081325_3K_dox_LampRFP_only_2.png
# Saved: ../images/converted\081325_3K_dox_LampRFP_only_3.png
# Saved: ../images/converted\081325_3K_dox_LampRFP_only_4.png
# Saved: ../images/converted\081325_3K_dox_LampRFP_only_5.png
# Saved: ../images/converted\081325_3K_dox_LampRFP_only_6.png
# Saved: ../images/converted\081325_3K_dox_MitoBFP_only_1.png
# Saved: ../images/converted\081325_3K_dox_MitoBFP_only_2.png
# Saved: ../images/converted\081325_3K_dox_MitoBFP_only_3.png
# Saved: ../images/converted\081325_3K_dox_MitoBFP_only_4.png
# Saved: ../images/converted\081325_3K_dox_MitoBFP_only_5.png
# Saved: ../images/converted\081325_3K_dox_MitoBFP_only_6.png
# Saved: ../images/converted\081325_3K_dox_only_1.png
# Saved: ../images/converted\081325_3K_dox_only_2.png
# Saved: ../images/converted\081325_3K_dox_only_3.png
# Saved: ../images/converted\081325_3K_dox_only_4.png
# Saved: ../images/converted\081325_3K_dox_only_5.png
# Saved: ../images/converted\081325_3K_dox_only_6.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_01.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_02.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_03.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_04.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_05.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_06.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_07.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_08.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_09.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_10.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_11.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_12.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_13.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_14.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_15.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_16.png
# Saved: ../images/converted\081425_3K_dox_LAMP1RFP_mitoBFP_17.png
# Saved: ../images/converted\081425_3K_dox_LampRFP_only_1.png
# Saved: ../images/converted\081425_3K_dox_LampRFP_only_2.png
# Saved: ../images/converted\081425_3K_dox_LampRFP_only_3.png
# Saved: ../images/converted\081425_3K_dox_LampRFP_only_4.png
# Saved: ../images/converted\081425_3K_dox_LampRFP_only_5.png
# Saved: ../images/converted\081425_3K_dox_LampRFP_only_6.png
# Saved: ../images/converted\081425_3K_dox_MitoBFP_only_1.png
# Saved: ../images/converted\081425_3K_dox_MitoBFP_only_2.png
# Saved: ../images/converted\081425_3K_dox_MitoBFP_only_3.png
# Saved: ../images/converted\081425_3K_dox_MitoBFP_only_4.png
# Saved: ../images/converted\081425_3K_dox_MitoBFP_only_5.png
# Saved: ../images/converted\081425_3K_dox_MitoBFP_only_6.png
# Saved: ../images/converted\081425_3K_dox_only_1.png
# Saved: ../images/converted\081425_3K_dox_only_2.png
# Saved: ../images/converted\081425_3K_dox_only_3.png
# Saved: ../images/converted\081425_3K_dox_only_4.png
# Saved: ../images/converted\081425_3K_dox_only_5.png
# Saved: ../images/converted\081425_3K_dox_only_6.png
# Saved: ../images/converted\72425_3K_doxonly_01.png
# Saved: ../images/converted\72425_3K_doxonly_010.png
# Saved: ../images/converted\72425_3K_doxonly_011.png
# Saved: ../images/converted\72425_3K_doxonly_012.png
# Saved: ../images/converted\72425_3K_doxonly_013.png
# Saved: ../images/converted\72425_3K_doxonly_014.png
# Saved: ../images/converted\72425_3K_doxonly_015.png
# Saved: ../images/converted\72425_3K_doxonly_016.png
# Saved: ../images/converted\72425_3K_doxonly_02.png
# Saved: ../images/converted\72425_3K_doxonly_03.png
# Saved: ../images/converted\72425_3K_doxonly_04.png
# Saved: ../images/converted\72425_3K_doxonly_05.png
# Saved: ../images/converted\72425_3K_doxonly_06.png
# Saved: ../images/converted\72425_3K_doxonly_07.png
# Saved: ../images/converted\72425_3K_doxonly_08.png
# Saved: ../images/converted\72425_3K_doxonly_09.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_01.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_010.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_011.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_012.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_013.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_014.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_015.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_016.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_017.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_018.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_019.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_02.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_020.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_021.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_022.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_023.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_024.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_025.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_03.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_04.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_05.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_06.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_07.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_08.png
# Saved: ../images/converted\72425_3K_dox_LAMP1RFP_mitoBFP_09.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_04.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_05.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_06.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_07.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_08.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_09.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_10.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_11.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_12.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_13.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_14.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_15.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_16.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_17.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_18.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_19.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_20.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_21.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_22 DO NOT USE.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_23.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_24.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_25.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_26.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_27czi.png
# Saved: ../images/converted\73025_3K_dox_LAMP1RFP_mitoBFP_28czi.png
# Saved: ../images/converted\73025_3K_dox_only_1.png
# Saved: ../images/converted\73025_3K_dox_only_2.png
# Saved: ../images/converted\73025_3K_dox_only_3.png
# Saved: ../images/converted\73025_3K_dox_only_4.png
# Saved: ../images/converted\73025_3K_dox_only_5.png
# Saved: ../images/converted\73025_3K_dox_only_6.png
